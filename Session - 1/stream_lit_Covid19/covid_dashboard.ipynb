# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Loading Data

# %%
covid_19_cases = pd.read_csv("./covid_datasets/WHO-COVID-19-global-data.csv")
covid_19_vaccination_data = pd.read_csv("./covid_datasets/vaccination-data.csv")

# %% [markdown]
# # Visualizing the Dataframes.

# %%
covid_19_cases.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
covid_19_vaccination_data.head()
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2022-10-16
# 1         Albania  ALB       EURO   REPORTING   2022-10-16
# 2         Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3  American Samoa  ASM       WPRO   REPORTING   2022-08-23
# 4         Andorra  AND       EURO   REPORTING   2022-10-16
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0          11977773.0                     11012345.0
# 1           2991576.0                      1339100.0
# 2          15267442.0                      7840131.0
# 3            111316.0                        44885.0
# 4            154320.0                        57898.0
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                     30.769                                28.289
# 1                    104.000                                47.053
# 2                     34.817                                17.879
# ...

# %%
! streamlit run covid-dashboard-app.py
